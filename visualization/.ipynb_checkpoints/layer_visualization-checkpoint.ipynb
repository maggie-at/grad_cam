# %%
import os
import sys
import numpy as np
from tqdm import tqdm

import cv2
from PIL import Image
import matplotlib.pyplot as plt

import torch
from torchvision import models, transforms

# %%
sys.path.append('..')  # 添加上级目录到搜索路径

from utils.layer_utils import GradCAM, show_cam_on_image

# %%
def cnn_cam(data_path, res_path, num_classes):
    model = models.resnet34()
    in_channel = model.fc.in_features
    model.fc = torch.nn.Linear(in_channel, num_classes)
    model.load_state_dict(torch.load('/home/ubuntu/workspace/hy/grad_cam/train_model/resnet/resNet34-dagm-1026.pth', map_location='cpu'))
    
    # LayerCam & WeightCam替换一下utils文件
    # target_layers = [model.layer4]

    # target_layers = [model.layer3]

    # target_layers = [model.layer2]
    
    # target_layers = [model.layer1]


    data_transform = transforms.Compose([transforms.ToTensor(),
                                         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
    
    cam = GradCAM(model=model, target_layers=target_layers, use_cuda=False)
    
    cls_folder_path = os.path.join(data_path, "defect/")

    target_category = 0

    for img_file in tqdm(os.listdir(cls_folder_path), desc="Processing: "):
        img_path = os.path.join(cls_folder_path, img_file)
        # load image
        assert os.path.exists(img_path), "file: '{}' dose not exist.".format(img_path)
        img = Image.open(img_path).convert('RGB')
        img = np.array(img, dtype=np.uint8)

        # [C, H, W]
        img_tensor = data_transform(img)
        # [C, H, W] -> [N, C, H, W]
        input_tensor = torch.unsqueeze(img_tensor, dim=0)
        grayscale_cam = cam(input_tensor=input_tensor, target_category=target_category)
        grayscale_cam = grayscale_cam[0, :]
        visualization = show_cam_on_image(img.astype(dtype=np.float32) / 255.,
                                        grayscale_cam,
                                        use_rgb=True)
        plt.imshow(visualization)
        
        grayscale_cam_8bit = (grayscale_cam * 255).astype('uint8')
        
        # 设置每个类别的分割阈值
        _, thresh = cv2.threshold(grayscale_cam_8bit, 127, 255, cv2.THRESH_BINARY)
        
        # 画出预测框
        contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            area = w * h
            # 忽略面积小于64的预测框
            if area >= 64:
                cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        plt.show(img)

        break

# %%
cnn_cam(data_path='/home/ubuntu/workspace/hy/dataset/DAGM/val/',
        res_path='/home/ubuntu/workspace/hy/dataset/DAGM/result/predict/',
        num_classes=2)
# Out:
# Processing:   0%|                                                                                                                                                                                                            | 0/1054 [00:00<?, ?it/s]
# Processing:   0%|                                                                                                                                                                                                            | 0/1054 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cnn_cam(data_path='/home/ubuntu/workspace/hy/dataset/DAGM/val/',
#       2         res_path='/home/ubuntu/workspace/hy/dataset/DAGM/result/predict/',
#       3         num_classes=2)
#
# Cell In[23], line 57, in cnn_cam(data_path, res_path, num_classes)
#      55     if area >= 64:
#      56         cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
# ---> 57 plt.show(img)
#      59 break
#
# File ~/anaconda3/envs/TSCAM/lib/python3.9/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/anaconda3/envs/TSCAM/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
# ---> 98 if close and Gcf.get_all_fig_managers():
#      99     matplotlib.pyplot.close('all')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
